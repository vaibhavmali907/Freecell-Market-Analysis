# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cust=pd.read_csv(r"employee.csv")

# %%
cust.head()

# %%
df=cust[cust['BusinessTravel']=='Travel_Frequently']

# %%
df

# %%
#Q1
a=df[df['JobRole']=='Research Scientist']

# %%
a

# %%
b=a[a['Department']=='Research & Development']

# %%
b

# %%
c=b[b['JobSatisfaction']>=4]

# %%
c

# %%
d=c[c['PerformanceRating']>=4]

# %%
d

# %%
e=d[d['EducationField']!='Life Sciences']

# %%
e

# %%
#Q2
customer=pd.read_csv(r"employee.csv")

# %%
customer.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df=customer[customer['BusinessTravel']=='Travel_Frequently']

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 26     32       Yes  Travel_Frequently       1125  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
a=df[df['JobRole']=='Sales Executive']

# %%
b=a[a['Department']=='Sales']

# %%
c=b[b['EducationField']=='Marketing']

# %%
d=c[c['JobSatisfaction']>=4]

# %%
e=d[d['PerformanceRating']>=4]

# %%
e
# Out:
#     Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 48   46        No  Travel_Frequently       1211      Sales                 5
#
#     Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 48          4      Marketing              1              62  ...
#
#     RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 48                         3            80                 0
#
#     TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 48                 14                      4               3               9
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 48                  6                        0                     8
#
# [1 rows x 35 columns]

# %%
#Q3
hr=pd.read_csv(r"employee.csv")

# %%
hr.head(50)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df=hr[hr['BusinessTravel']=='Travel_Frequently']

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 26     32       Yes  Travel_Frequently       1125  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
a=df[df['JobSatisfaction']>=4]

# %%
b=a[a['PerformanceRating']>=4]

# %%
b
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 44     30        No  Travel_Frequently        721  Research & Development
# 48     46        No  Travel_Frequently       1211                   Sales
# 385    30       Yes  Travel_Frequently        464  Research & Development
# 395    43        No  Travel_Frequently        313  Research & Development
# 416    38        No  Travel_Frequently       1490  Research & Development
# 509    33        No  Travel_Frequently       1296  Research & Development
# 521    27        No  Travel_Frequently       1410                   Sales
# 627    52        No  Travel_Frequently        890  Research & Development
# 974    27        No  Travel_Frequently        793                   Sales
# 1076   54        No  Travel_Frequently       1050  Research & Development
# 1166   48        No  Travel_Frequently        365  Research & Development
# 1186   35       Yes  Travel_Frequently        880                   Sales
# ...
